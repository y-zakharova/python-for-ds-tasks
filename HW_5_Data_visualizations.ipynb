# %% [markdown]
# # Домашнє завдання до лекції 5: візуалізація даних.
# В цьому ДЗ ми будемо багато працювати не тільки з візуалізаціями, а і з функціоналом pandas, адже візуалізація даних - це частина аналізу даних та працює спільно з агрегацією та фільтрацією наших даних. До того ж перед тим, як аналізувати дані, їх треба почистити. Чим ми і займемось.

# %% [markdown]
# 0.Імпортуйте matplotlib.pyplot, seaborn та pandas.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Набір даних Taxis

# %% [markdown]
# Використовуючи метод з бібліотеки `seaborn` `load_dataset` ми завантажимо перший набір даних для аналізу. Завантажимо дані так, бо це зручно + аби ви знали, що є і така можливість знайти собі набір даних для експериментів.
# Набір даних містить поїздки таксі у Нью Йорку у 2019 році. Детальний опис на [сайті](https://www.nyc.gov/site/tlc/about/tlc-trip-record-data.page).
#
# Які колонки мість набір даних:
# - `pickup` - час початку поїздки
# - `dropoff` - час закінчення поїздки
# - `passengers` - кількість пасажирів у поїздці
# - `distance` - відстань поіздки
# - `fare` - базова плата за поїздку
# - `tip` - розмір чайових
# - `tolls` - плата за платні дороги (за це також платить пасажир)
# - `total` - сумарна плата за поїздку
# - `color` - колір авто, яке здійснювало поїздку
# - `payment` - метод оплати
# - `pickup_zone` - зона, у якій почалась поїздка
# - `dropoff_zone` - зона, у якій закінчилась поїздка
# - `pickup_borough` - район, у якому почалась поїздка
# - `dropoff_borough` - район, у якому закінчилась поїздка
#
# Назви ознак здбільшого говорять самі за себе. Слово borough перекладається з англійської як "район".
#
# Ми будемо працювати сами з тим шматочком даних, які наявні в seaborn.
# Переглянути всі набори даних з seaborn можна [тут](https://github.com/mwaskom/seaborn-data).
#
# Спершу - завантажуємо дані - просто виконайте клітинку нижче.

# %%
df_taxi = sns.load_dataset('taxis')

# %% [markdown]
# 1.Виведіть
# - перші 3 записи з набору даних
# - типи даних в наборі даних df_taxi
# - розміри набору даних

# %%
df_taxi[:3]
# Out:
#                pickup             dropoff  passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5  2.36
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
#
#             dropoff_zone pickup_borough dropoff_borough
# 0    UN/Turtle Bay South      Manhattan       Manhattan
# 1  Upper West Side South      Manhattan       Manhattan
# 2           West Village      Manhattan       Manhattan

# %%
df_taxi.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
df_taxi.shape
# Out:
# (6433, 14)

# %% [markdown]
# 2.Перевіримо, чи є в цьому наборі даних пропущені значення. Для цього можемо вивести кількість пропущених значень в кожній колонці наступним чином (це надзвичайно корисна команда, запамʼятайте її):

# %%
df_taxi.isna().sum()
# Out:
# pickup              0
# dropoff             0
# passengers          0
# distance            0
# fare                0
# tip                 0
# tolls               0
# total               0
# color               0
# payment            44
# pickup_zone        26
# dropoff_zone       45
# pickup_borough     26
# dropoff_borough    45
# dtype: int64

# %% [markdown]
# 4050   0.00   0.00  144.30  yellow         cash          LaGuardia Airport
# 4118   5.06   0.00   30.36  yellow  credit card                        NaN
# 4127   0.00   0.00    3.80  yellow         cash                        NaN
# 4219  10.00   5.76  113.56  yellow  credit card                JFK Airport
# 4281   2.06   0.00   12.36  yellow  credit card                        NaN
# 4414   4.80   5.76   28.86  yellow  credit card                        NaN
# 4466   0.00   0.00   47.30  yellow         cash             Midtown Center
# 4772   1.46   0.00    8.76  yellow  credit card                        NaN
# 4815  20.56   0.00  123.36  yellow  credit card       TriBeCa/Civic Center
# 4941   2.50   0.00   10.80  yellow  credit card                        NaN
# 5263   5.16   0.00   30.96  yellow  credit card                        NaN
# 5493   0.00   0.00   10.00   green  credit card                        NaN
# 5612   0.00   0.00   12.30   green         cash            Jackson Heights
# 5624   0.00   0.00    3.30   green         cash                        NaN
# 5638   0.00   0.00   10.00   green  credit card                        NaN
# 5648   0.00  18.90  169.70   green         cash              East Flushing
# 6083   0.00   0.00    5.00   green  credit card                        NaN
# 6118   0.00   0.00   25.50   green  credit card           Prospect Heights
# 6314   0.00   0.00   25.00   green         cash                    Jamaica
# 6356   0.00   0.00    4.80   green         cash         Stuyvesant Heights
#
#      dropoff_zone pickup_borough dropoff_borough
# 42            NaN            NaN             NaN
# 622           NaN            NaN             NaN
# 711           NaN      Manhattan             NaN
# 739           NaN      Manhattan             NaN
# 970           NaN            NaN             NaN
# 1108          NaN            NaN             NaN
# 1112          NaN      Manhattan             NaN
# 1230          NaN      Manhattan             NaN
# 1690          NaN       Brooklyn             NaN
# 1787          NaN      Manhattan             NaN
# 2089          NaN         Queens             NaN
# 2137          NaN            NaN             NaN
# 2180          NaN      Manhattan             NaN
# 2231          NaN      Manhattan             NaN
# 2402          NaN         Queens             NaN
# 2571          NaN      Manhattan             NaN
# 2742          NaN            NaN             NaN
# 2905          NaN         Queens             NaN
# 3085          NaN            NaN             NaN
# 3241          NaN         Queens             NaN
# 3259          NaN            NaN             NaN
# 3500          NaN         Queens             NaN
# 3644          NaN            NaN             NaN
# 3661          NaN         Queens             NaN
# 3889          NaN            NaN             NaN
# 4050          NaN         Queens             NaN
# 4118          NaN            NaN             NaN
# 4127          NaN            NaN             NaN
# 4219          NaN         Queens             NaN
# 4281          NaN            NaN             NaN
# 4414          NaN            NaN             NaN
# 4466          NaN      Manhattan             NaN
# 4772          NaN            NaN             NaN
# 4815          NaN      Manhattan             NaN
# 4941          NaN            NaN             NaN
# 5263          NaN            NaN             NaN
# 5493          NaN            NaN             NaN
# 5612          NaN         Queens             NaN
# 5624          NaN            NaN             NaN
# 5638          NaN            NaN             NaN
# 5648          NaN         Queens             NaN
# 6083          NaN            NaN             NaN
# 6118          NaN       Brooklyn             NaN
# 6314          NaN         Queens             NaN
# 6356          NaN       Brooklyn             NaN

# %% [markdown]
# Деякі відсутні дані у нас в колонках, що повʼязані з геолокацією юзера (pickup_zone, dropoff_zone, pickup_borough, dropoff_borough) та методом оплати (payment).
#
# 4801   0.00  12.30  yellow     NaN            TriBeCa/Civic Center
# 4842   0.00  14.30  yellow     NaN                     Murray Hill
# 4915   0.00  10.30  yellow     NaN           Upper East Side South
# 4955   0.00  22.30  yellow     NaN                    West Village
# 5046   0.00  16.30  yellow     NaN       West Chelsea/Hudson Yards
# 5068   0.00   6.80  yellow     NaN           Upper West Side North
# 5207   0.00  16.30  yellow     NaN    Penn Station/Madison Sq West
# 5284   0.00   5.80  yellow     NaN                   Midtown North
# 5586   0.00   6.80   green     NaN                Hamilton Heights
# 5809   0.00   4.80   green     NaN             Morningside Heights
# 5821   0.00   4.30   green     NaN             Crown Heights South
# 6169   0.00   4.30   green     NaN                 Jackson Heights
# 6311   0.00   5.30   green     NaN  Long Island City/Hunters Point
#
#                         dropoff_zone pickup_borough dropoff_borough
# 7                           Flatiron      Manhattan       Manhattan
# 445                  Columbia Street       Brooklyn        Brooklyn
# 491                      Murray Hill      Manhattan       Manhattan
# 545                     Forest Hills         Queens          Queens
# 621            Upper East Side South      Manhattan       Manhattan
# 770                      JFK Airport         Queens          Queens
# 913              Lincoln Square West      Manhattan       Manhattan
# 953             Central Harlem North      Manhattan       Manhattan
# 1207                       Hudson Sq      Manhattan       Manhattan
# 1372                Garment District      Manhattan       Manhattan
# 1566                  Bushwick South      Manhattan        Brooklyn
# 1690                             NaN       Brooklyn             NaN
# 1704                  Bushwick South      Manhattan        Brooklyn
# 1737                    Baisley Park         Queens          Queens
# 1851           Upper East Side South      Manhattan       Manhattan
# 1860           Upper East Side North      Manhattan       Manhattan
# 1929                     JFK Airport         Queens          Queens
# 1941                     Murray Hill      Manhattan       Manhattan
# 2353             Little Italy/NoLiTa      Manhattan       Manhattan
# 2444       Times Sq/Theatre District      Manhattan       Manhattan
# 3109       Times Sq/Theatre District      Manhattan       Manhattan
# 3372                   Midtown North      Manhattan       Manhattan
# 3793                    Midtown East            NaN       Manhattan
# 3803    Penn Station/Madison Sq West         Queens       Manhattan
# 3983                    Forest Hills      Manhattan          Queens
# 4230                        Union Sq      Manhattan       Manhattan
# 4384             Morningside Heights      Manhattan       Manhattan
# 4474  Stuy Town/Peter Cooper Village      Manhattan       Manhattan
# 4515       West Chelsea/Hudson Yards      Manhattan       Manhattan
# 4562  Long Island City/Hunters Point         Queens          Queens
# 4746   Meatpacking/West Village West      Manhattan       Manhattan
# 4801               Battery Park City      Manhattan       Manhattan
# 4842                    West Village      Manhattan       Manhattan
# 4915                     Murray Hill      Manhattan       Manhattan
# 4955           Upper East Side South      Manhattan       Manhattan
# 5046           Upper West Side South      Manhattan       Manhattan
# 5068           Upper West Side North      Manhattan       Manhattan
# 5207             Lincoln Square East      Manhattan       Manhattan
# 5284                   Midtown North      Manhattan       Manhattan
# 5586                  West Concourse      Manhattan           Bronx
# 5809                Hamilton Heights      Manhattan       Manhattan
# 5821             Crown Heights South       Brooklyn        Brooklyn
# 6169                 Jackson Heights         Queens          Queens
# 6311  Long Island City/Hunters Point         Queens          Queens

# %%
df_taxi[df_taxi['distance'] == 0][df_taxi['total'] != 0]
# Out:
# <ipython-input-59-acf3b5d20a66>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df
# 5697   0.00   0.00    3.30   green         cash
# 5721   0.00   0.00    3.30   green         cash
# 5796   0.00   0.00    4.30   green         cash
# 5957   0.00   0.00   10.30   green         cash
# 6080   0.00   0.00    8.00   green  credit card
# 6083   0.00   0.00    5.00   green  credit card
# 6117   0.00   0.00    4.80   green  credit card
# 6118   0.00   0.00   25.50   green  credit card
# 6129   0.00   0.00    7.00   green         cash
# 6244   0.00   0.00    3.30   green         cash
# 6314   0.00   0.00   25.00   green         cash
# 6355   0.00   0.00    3.30   green  credit card
# 6356   0.00   0.00    4.80   green         cash
# 6357   0.00   0.00    3.30   green  credit card
# 6372   0.00   0.00    3.30   green         cash
# 6393   0.00   0.00   72.00   green  credit card
#
#                          pickup_zone                    dropoff_zone  \
# 42                               NaN                             NaN
# 120                      JFK Airport                     JFK Airport
# 622                              NaN                             NaN
# 670                  Lenox Hill East                 Lenox Hill East
# 970                              NaN                             NaN
# 1080                     JFK Airport                     JFK Airport
# 1207                       Hudson Sq                       Hudson Sq
# 1482             Lincoln Square East             Lincoln Square East
# 1690                   East New York                             NaN
# 1910         Queensbridge/Ravenswood         Queensbridge/Ravenswood
# 1929                     JFK Airport                     JFK Airport
# 2398                         Seaport               Battery Park City
# 2742                             NaN                             NaN
# 3095                  Midtown Center                  Midtown Center
# 3109       Times Sq/Theatre District       Times Sq/Theatre District
# 3221                    Clinton East                    Clinton East
# 3238                Garment District                Garment District
# 3377        Financial District North              World Trade Center
# 3644                             NaN                             NaN
# 3889                             NaN                             NaN
# 4118                             NaN                             NaN
# 4264                 Lenox Hill East                 Lenox Hill East
# 4483                    East Chelsea                    East Chelsea
# 4550  Long Island City/Hunters Point  Long Island City/Hunters Point
# 4663  Long Island City/Hunters Point  Long Island City/Hunters Point
# 4955                    West Village           Upper East Side South
# 4972                   Midtown South                   Midtown South
# 5433            TriBeCa/Civic Center            TriBeCa/Civic Center
# 5493                             NaN                             NaN
# 5545            Flatbush/Ditmas Park            Flatbush/Ditmas Park
# 5546         Queensbridge/Ravenswood         Queensbridge/Ravenswood
# 5624                             NaN                             NaN
# 5638                             NaN                             NaN
# 5678     Downtown Brooklyn/MetroTech     Downtown Brooklyn/MetroTech
# 5683         Queensbridge/Ravenswood         Queensbridge/Ravenswood
# 5697                   Dyker Heights                   Dyker Heights
# 5721                     Hunts Point                     Hunts Point
# 5796                         Astoria                         Astoria
# 5957                        Steinway                       Sunnyside
# 6080                     Fort Greene                     Fort Greene
# 6083                             NaN                             NaN
# 6117                  Bushwick South                  Bushwick South
# 6118                Prospect Heights                             NaN
# 6129                  Manhattanville                  Manhattanville
# 6244         Queensbridge/Ravenswood         Queensbridge/Ravenswood
# 6314                         Jamaica                             NaN
# 6355                         Astoria                         Astoria
# 6356              Stuyvesant Heights                             NaN
# 6357                        Rosedale                        Rosedale
# 6372                     Cobble Hill                     Cobble Hill
# 6393                     Parkchester            Flatbush/Ditmas Park
#
#      pickup_borough dropoff_borough
# 42              NaN             NaN
# 120          Queens          Queens
# 622             NaN             NaN
# 670       Manhattan       Manhattan
# 970             NaN             NaN
# 1080         Queens          Queens
# 1207      Manhattan       Manhattan
# 1482      Manhattan       Manhattan
# 1690       Brooklyn             NaN
# 1910         Queens          Queens
# 1929         Queens          Queens
# 2398      Manhattan       Manhattan
# 2742            NaN             NaN
# 3095      Manhattan       Manhattan
# 3109      Manhattan       Manhattan
# 3221      Manhattan       Manhattan
# 3238      Manhattan       Manhattan
# 3377      Manhattan       Manhattan
# 3644            NaN             NaN
# 3889            NaN             NaN
# 4118            NaN             NaN
# 4264      Manhattan       Manhattan
# 4483      Manhattan       Manhattan
# 4550         Queens          Queens
# 4663         Queens          Queens
# 4955      Manhattan       Manhattan
# 4972      Manhattan       Manhattan
# 5433      Manhattan       Manhattan
# 5493            NaN             NaN
# 5545       Brooklyn        Brooklyn
# 5546         Queens          Queens
# 5624            NaN             NaN
# 5638            NaN             NaN
# 5678       Brooklyn        Brooklyn
# 5683         Queens          Queens
# 5697       Brooklyn        Brooklyn
# 5721          Bronx           Bronx
# 5796         Queens          Queens
# 5957         Queens          Queens
# 6080       Brooklyn        Brooklyn
# 6083            NaN             NaN
# 6117       Brooklyn        Brooklyn
# 6118       Brooklyn             NaN
# 6129      Manhattan       Manhattan
# 6244         Queens          Queens
# 6314         Queens             NaN
# 6355         Queens          Queens
# 6356       Brooklyn             NaN
# 6357         Queens          Queens
# 6372       Brooklyn        Brooklyn
# 6393          Bronx        Brooklyn

# %% [markdown]
# Є рядки, де дистанція = 0, але оплата ненульова. Це може бути повʼязано з відміною замовлення, коли водій вже приїхав, або дуже довгим очікуванням клієнта (якраз в даних бачимо, що різниця в часі або декілька секунд, або десятки хвилин).

# %% [markdown]
# 3.Заповнимо пусті значення. Оскільки всі колонки набору даних мають пропущені значення в рядках з типом даних рядок, заповнимо пропущені значення рядком `NA`.
# Створіть набір даних `df_taxi_clean`, який містить дані `df_taxi` із заповненими пропущеними значеннями у всіх колонках (де ті значення відсутні) значенням `NA`.
#
# **УВАГА!** Надалі в роботі треба використовувати `df_taxi_clean`, ми ж його і створили для того, аби далі ним користуватись :)

# %%
df_taxi_clean = df_taxi.fillna('NA')

# %% [markdown]
# Після виконання завдання запустіть наступну клітинку:

# %%
df_taxi_clean.isna().sum()
# Out:
# pickup             0
# dropoff            0
# passengers         0
# distance           0
# fare               0
# tip                0
# tolls              0
# total              0
# color              0
# payment            0
# pickup_zone        0
# dropoff_zone       0
# pickup_borough     0
# dropoff_borough    0
# dtype: int64

# %% [markdown]
# 4.Хочеться подивитись на дані у динаміці. Перетворіть колонку `pickup` набору даних `df_taxi_clean` (нам нема чого працювати з "брудними" даними, якщо ми їх вже почистили, але хай будуть в окремій змінній про всяк випадок) у формат `datetime64[ns]`. Результат перетворення збережіть в тій самій колонці `pickup`.

# %%
# вже у потрібному форматі
df_taxi_clean.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers                  int64
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %% [markdown]
# Після виконання завдання запустіть наступну клітинку:

# %%
df_taxi_clean.pickup.head(3)
# Out:
# 0   2019-03-23 20:21:09
# 1   2019-03-04 16:11:55
# 2   2019-03-27 17:53:01
# Name: pickup, dtype: datetime64[ns]

# %% [markdown]
# 5.У нас колонка pickup зараз мість дані у форматі дата-час. Пропоную прибрати час і зробити аналітику по дням. Для цього виконайте клатинку нижче:

# %%
df_taxi_clean['pickup']
# Out:
# 0      2019-03-23 20:21:09
# 1      2019-03-04 16:11:55
# 2      2019-03-27 17:53:01
# 3      2019-03-10 01:23:59
# 4      2019-03-30 13:27:42
#                ...
# 6428   2019-03-31 09:51:53
# 6429   2019-03-31 17:38:00
# 6430   2019-03-23 22:55:18
# 6431   2019-03-04 10:09:25
# 6432   2019-03-13 19:31:22
# Name: pickup, Length: 6433, dtype: datetime64[ns]

# %%
df_taxi_clean['pickup_day'] = df_taxi_clean.pickup.dt.floor('d')

# %%
df_taxi_clean['pickup_day']
# Out:
# 0      2019-03-23
# 1      2019-03-04
# 2      2019-03-27
# 3      2019-03-10
# 4      2019-03-30
#           ...
# 6428   2019-03-31
# 6429   2019-03-31
# 6430   2019-03-23
# 6431   2019-03-04
# 6432   2019-03-13
# Name: pickup_day, Length: 6433, dtype: datetime64[ns]

# %% [markdown]
# А тепер згрупуйте дані по pickup_day та виведіть графік сумарних платежів по дням. Після виведення графіку скажіть, чи бачите щось дивне на ньому?

# %%
df_taxi_clean.groupby('pickup_day')['total'].sum().plot();

# %% [markdown]
# Дивно, що 2019-02-28 лише один запис. Також спостерігається певна сезонність

# %% [markdown]
# 6.Виведіть кількість рядків для кожного pickup_day.

# %%
df_taxi_clean['pickup_day'].value_counts().sort_index()
# Out:
# 2019-02-28      1
# 2019-03-01    241
# 2019-03-02    198
# 2019-03-03    169
# 2019-03-04    171
# 2019-03-05    228
# 2019-03-06    257
# 2019-03-07    218
# 2019-03-08    235
# 2019-03-09    204
# 2019-03-10    185
# 2019-03-11    209
# 2019-03-12    218
# 2019-03-13    244
# 2019-03-14    260
# 2019-03-15    201
# 2019-03-16    220
# 2019-03-17    178
# 2019-03-18    173
# 2019-03-19    201
# 2019-03-20    233
# 2019-03-21    221
# 2019-03-22    229
# 2019-03-23    209
# 2019-03-24    149
# 2019-03-25    155
# 2019-03-26    178
# 2019-03-27    232
# 2019-03-28    205
# 2019-03-29    209
# 2019-03-30    215
# 2019-03-31    187
# Name: pickup_day, dtype: int64

# %% [markdown]
# Маєте побачити, що для дати 2019-02-28 є тільки один рядок. Це запис, який, схоже, потрапив сюди випадково, видаліть з набору даних df_taxi_clean рядок, що містить pickup_day рівний 2019-02-28. Та знову виведіть графік сумарних платежів по pickup_day.

# %%
df_taxi_clean.drop(df_taxi_clean[df_taxi_clean['pickup_day'] == '2019-02-28'].index, inplace=True)
df_taxi_clean.shape
# Out:
# (6432, 15)

# %%
df_taxi_clean['pickup_day'].value_counts().sort_index()
# Out:
# 2019-03-01    241
# 2019-03-02    198
# 2019-03-03    169
# 2019-03-04    171
# 2019-03-05    228
# 2019-03-06    257
# 2019-03-07    218
# 2019-03-08    235
# 2019-03-09    204
# 2019-03-10    185
# 2019-03-11    209
# 2019-03-12    218
# 2019-03-13    244
# 2019-03-14    260
# 2019-03-15    201
# 2019-03-16    220
# 2019-03-17    178
# 2019-03-18    173
# 2019-03-19    201
# 2019-03-20    233
# 2019-03-21    221
# 2019-03-22    229
# 2019-03-23    209
# 2019-03-24    149
# 2019-03-25    155
# 2019-03-26    178
# 2019-03-27    232
# 2019-03-28    205
# 2019-03-29    209
# 2019-03-30    215
# 2019-03-31    187
# Name: pickup_day, dtype: int64

# %% [markdown]
# 7.Давайте подивимось на динаміку сумарних платежів по районам. Для цього сформуйте на основі `df_taxi_clean` зводну таблицю, де рядками є `pickup_day`, колонками `pickup_borough`, а значенням - сума платежів. Запишіть зводну таблицю в змінну `borough_pivot`. Наостанок, вилучіть колонку зі значенням `pickup_borough` рівним `NA` - уявімо, що ці дані нас не цікавлять.

# %%
borough_pivot = df_taxi_clean.pivot_table(
    index=['pickup_day'],
    columns=['pickup_borough'],
    values='total',
    aggfunc='sum'
)

# %%
borough_pivot
# Out:
# pickup_borough   Bronx  Brooklyn  Manhattan      NA  Queens
# pickup_day
# 2019-03-01      123.42    353.05    3169.47   14.60  553.29
# 2019-03-02         NaN    146.56    2716.33     NaN  456.13
# 2019-03-03       80.75    407.06    2100.23   10.55  428.73
# 2019-03-04       92.00    188.73    2026.17     NaN  962.18
# 2019-03-05       98.16    558.40    2981.26     NaN  739.56
# 2019-03-06      130.65    198.53    3501.07   10.00  833.36
# 2019-03-07         NaN    440.75    3087.82     NaN  587.13
# 2019-03-08       79.20    237.47    3408.85   18.35  780.34
# 2019-03-09       80.22    187.88    2967.71   38.26  511.73
# 2019-03-10      119.86    160.48    2353.45   70.26  494.64
# 2019-03-11       46.04    254.92    3019.49    3.30  697.51
# 2019-03-12       31.83    158.74    2896.13  166.00  623.10
# 2019-03-13       42.44    287.68    3690.66   10.00  837.28
# 2019-03-14       82.53    255.84    3609.49     NaN  794.69
# 2019-03-15       94.32    336.91    3051.71   30.36  516.99
# 2019-03-16       34.80    334.22    2763.89     NaN  703.67
# 2019-03-17       64.63    166.92    2430.99     NaN  806.96
# 2019-03-18       23.10    132.07    2393.46   12.36  697.79
# 2019-03-19      166.28     97.11    2713.03  215.77  771.73
# 2019-03-20      104.88    100.42    3399.59     NaN  918.06
# 2019-03-21       32.56    253.08    3428.19    8.76  632.49
# 2019-03-22       35.53    328.07    3138.56     NaN  743.20
# 2019-03-23      147.63    192.90    2605.58   55.80  354.07
# 2019-03-24        7.30    180.04    1773.76   25.10  630.61
# 2019-03-25      142.47    149.27    1976.89     NaN  608.92
# 2019-03-26       21.80    173.45    2371.88     NaN  799.07
# 2019-03-27      183.29    127.77    3300.23     NaN  805.88
# 2019-03-28       72.53    236.75    2763.48     NaN  813.68
# 2019-03-29       63.18    115.97    2953.97   79.16  578.24
# 2019-03-30        3.80    359.74    2885.42  114.18  641.25
# 2019-03-31       48.56    246.70    2341.47     NaN  472.11

# %%
borough_pivot.drop(
    columns='NA',
    inplace=True
    )

# %%
borough_pivot
# Out:
# pickup_borough   Bronx  Brooklyn  Manhattan  Queens
# pickup_day
# 2019-03-01      123.42    353.05    3169.47  553.29
# 2019-03-02         NaN    146.56    2716.33  456.13
# 2019-03-03       80.75    407.06    2100.23  428.73
# 2019-03-04       92.00    188.73    2026.17  962.18
# 2019-03-05       98.16    558.40    2981.26  739.56
# 2019-03-06      130.65    198.53    3501.07  833.36
# 2019-03-07         NaN    440.75    3087.82  587.13
# 2019-03-08       79.20    237.47    3408.85  780.34
# 2019-03-09       80.22    187.88    2967.71  511.73
# 2019-03-10      119.86    160.48    2353.45  494.64
# 2019-03-11       46.04    254.92    3019.49  697.51
# 2019-03-12       31.83    158.74    2896.13  623.10
# 2019-03-13       42.44    287.68    3690.66  837.28
# 2019-03-14       82.53    255.84    3609.49  794.69
# 2019-03-15       94.32    336.91    3051.71  516.99
# 2019-03-16       34.80    334.22    2763.89  703.67
# 2019-03-17       64.63    166.92    2430.99  806.96
# 2019-03-18       23.10    132.07    2393.46  697.79
# 2019-03-19      166.28     97.11    2713.03  771.73
# 2019-03-20      104.88    100.42    3399.59  918.06
# 2019-03-21       32.56    253.08    3428.19  632.49
# 2019-03-22       35.53    328.07    3138.56  743.20
# 2019-03-23      147.63    192.90    2605.58  354.07
# 2019-03-24        7.30    180.04    1773.76  630.61
# 2019-03-25      142.47    149.27    1976.89  608.92
# 2019-03-26       21.80    173.45    2371.88  799.07
# 2019-03-27      183.29    127.77    3300.23  805.88
# 2019-03-28       72.53    236.75    2763.48  813.68
# 2019-03-29       63.18    115.97    2953.97  578.24
# 2019-03-30        3.80    359.74    2885.42  641.25
# 2019-03-31       48.56    246.70    2341.47  472.11

# %% [markdown]
# Далі запустіть наступну клітинку та дайте відповідь на питання, в якому районі найчастіше найбільша сума денних платежів за поїздки на таксі?
# До речі, також рекомендую спробувати запустити команду `borough_pivot.plot()` та зрозуміти, навіщо нам тут частина `fillna(0)`.

# %%
borough_pivot.fillna(0).plot();

# %% [markdown]
# Найбільша сума денних платежів в Манхеттені – це може бути повʼязане (потрібен додатковий аналіз) з кількістю поїздок в цьому районі, з їхньою дальністю, з розміром чайових

# %% [markdown]
# 8.Виведіть будь-яким способом гістограми суми денних платежів за поїздки по кожному з районів. Має бути 4 гістограми, на 4ох різних фігурах, або на одній.
# `Підказка:` Найпростіше це буде зробити, використавши `borough_pivot`.
# Пограйтесь з кількістю бінів. Яка кількість бінів на ваш погляд тут є вдалою? Чому?

# %%
borough_pivot.hist(bins=6);

# %% [markdown]
# На мою думку, найбільш вдалою є кількість бінів, що = 6, оскільки кількість даних невелика (близько 30) і більша кількість бінів не давала б достатньо розуміння тенденції

# %% [markdown]
# 9.Бачимо, що на окремих гістограмах у нас різні діапазони чеків. Припустимо, нам хочеться порівняти розподіли денних сум платежів по райнам. Давайте для цього виведемо 4 гістограми на одній фігурі. Вони звісно ж мають бути різного кольору і напівпрозорими для комфортного перегляду. Створіть гістограму максимально близьку до тої, що надана в очікуваному результаті.
# `Підказка:` ця візуалізація створена з допомогою pandas plotting.

# %%
plt.figure(figsize=(8, 6))
for col in borough_pivot.columns:
  plt.hist(borough_pivot[col], bins=6, alpha=.3, label=col)
plt.xlabel('Daily total')
plt.ylabel('Count of rides')
plt.title('Daily total distributions by boroughs')
plt.legend(loc='upper center')
plt.grid()
plt.show();

# %% [markdown]
# 10.З допомогою seaborn виведіть гістограми суми щомісячних платежів по кольорам автомобілів (колонка `color`). На одній фігурі має бути кількість гістограм рівна кількості різних кольорів автомобілів в наборі даних. Встановіть розмір фігури (10,5) та знайдіть значення dots-per-inch для фігури за якого якість зображення буде хорошою (зображення не буде розмитим).
# `Підказки:`
# 1. побудувати візуалізацію можна в один рядок коду, і ще один рядок - для встановлення розмірів і роздільної здатності фігури.
# 2. для зміни порядку відображення гістограм кольорів автомобілів (аби менша гістограма була перед, а не за більшою) можна посортувати датафрейм за полем кольору так, аби отримати той порядок, який вам потрібен.

# %%
plt.figure(figsize=(10,5), dpi=200)
sns.histplot(df_taxi_clean.sort_values(by='color'), x='total', hue='color');

# %% [markdown]
# 11.Цікаво, а чи є залежність між дальністю поїздки і розміром чайових? Побудуйте діаграму розсіювання між дальністю поїздки і розміром чайових. Можна побудувати графік будь-яким методом, який вам до вподоби, чи хочеться потренувати.
#
# В очікуваному результаті я надаю графік, який би будувала я. На наведеному прикладі найскладніша частина - це зробити червоною цю лінію тренду (вона побудована з допомогою спеціального типу графіку в seaborn). Аби вказати колір лінії в тому типу графіку треба зазначити в параметрі `line_kws`, що ми хочемо лінію червоного кольору. Але якщо у вас не буде виходити лінія червоного кольору - нехай буде синього - це не критично :)

# %%
sns.set(style="ticks")

fig, ax = plt.subplots(figsize=(8, 6))
sns.regplot(
    x='tip',
    y='distance',
    data=df_taxi_clean,
    ax=ax,
    line_kws={'color': 'red'},
    scatter_kws={'alpha': .25, 's': 70}
    )

plt.show()

# %% [markdown]
# Можна стверджувати, що є кореляція між дистанцією та розміром чайових

# %% [markdown]
# 12.Дайте відповідь на питання: що означає пряма лінія з точок, паралельна осі, за якою розташована дальність поїздки?

# %% [markdown]
# Це означає, що частина поїздок (в незалежності від дальності поїздки) залишаються без чайових.

# %% [markdown]
# 13.Побудуйте поденну динаміку чайових по районам, в яких забрали пасажира. Можна побудувати графік будь-яким методом, який вам до вподоби, чи хочеться потренувати. Важливо, щоб на одному графіку було 4 лінії (всі райони, крім `NA`), які відображають динаміку чайових, була легенда і були підписи вісей. В очікуваному результаті я надаю графік, який би будувала я.
#
# Дайте відповіді на питання:
# - при початку поїздки в якому районі **найнижчий середній розмір** чайових?
# - а в поїздках з якого району **найвищий середній розмір** чайових?
# - при проїздках з його району розмір чайових найстабільніший (найменше змінюється з дня у день)?

# %%
pickup_series = df_taxi_clean[df_taxi_clean['pickup_borough'] != 'NA'].groupby(['pickup_day', 'pickup_borough'])['tip'].mean()
pickup_series
# Out:
# pickup_day  pickup_borough
# 2019-03-01  Bronx             0.194286
#             Brooklyn          0.922353
#             Manhattan         2.043161
#             Queens            1.300000
# 2019-03-02  Brooklyn          0.681000
#                                 ...
# 2019-03-30  Queens            3.077083
# 2019-03-31  Bronx             0.000000
#             Brooklyn          1.311538
#             Manhattan         1.926797
#             Queens            1.699000
# Name: tip, Length: 122, dtype: float64

# %%
pickup_df = pickup_series.reset_index()
pickup_df.columns = ['pickup_day', 'pickup_borough', 'tip']
pickup_df = pickup_df.fillna(0)

pickup_df
# Out:
#     pickup_day pickup_borough       tip
# 0   2019-03-01          Bronx  0.194286
# 1   2019-03-01       Brooklyn  0.922353
# 2   2019-03-01      Manhattan  2.043161
# 3   2019-03-01         Queens  1.300000
# 4   2019-03-02       Brooklyn  0.681000
# ..         ...            ...       ...
# 117 2019-03-30         Queens  3.077083
# 118 2019-03-31          Bronx  0.000000
# 119 2019-03-31       Brooklyn  1.311538
# 120 2019-03-31      Manhattan  1.926797
# 121 2019-03-31         Queens  1.699000
#
# [122 rows x 3 columns]

# %%
sns.set(style="ticks")

fig, ax = plt.subplots(figsize=(12, 8))

sns.lineplot(
    data=pickup_df,
    x='pickup_day',
    y='tip',
    hue='pickup_borough'
    )

plt.show()

# %% [markdown]
# 1-2. Найвищий середній розмір чайових у районі Queens, найнижчий – Bronx.
# 3. Найстабільшій – у Manhattan

# %% [markdown]
# 14.Побудуйте box-plot розміру чайових по району (всі райони, крім `NA`) старту поїздки. Можна побудувати графік будь-яким методом, який вам до вподоби, чи хочеться потренувати.

# %%
sns.set(style="ticks")

fig, ax = plt.subplots(figsize=(8, 6))

sns.boxplot(data=df_taxi_clean[df_taxi_clean['pickup_borough'] != 'NA'], x='pickup_borough', y='tip')

plt.show()

# %% [markdown]
# 15.Творче завдання. Стовріть ТРИ інформативних візуалізації, які б допомогли в аналізі цих даних.
#
# Що вам було б цікаво дізнатись про ці поїздки? Як це можна було б використати при прийнятті рішень бізнесом?
# Наприклад, якщо найбільше поїздок в певний час доби, значить, треба стимулювати водіїв працювати в ці години. Якщо найбільше поїздок з певного району - треба тримати там запас авто, які б могли взяти пасажирів і т.д.
# Не обмежуйте свою фантазію.
#
# Візуалізації мають бути не тими, на які ми вже побудували вище. Але можна створювати аналогічні, просто з використанням інших полів даних. І описати, що ви бачите з тих візуалізацій.
# Кожна візуалізація оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат.

# %% [markdown]
# 1. Розподіл кількості пасажирів в залежності від району

# %%
df_taxi_clean['passengers'] = df_taxi_clean['passengers'].astype('category')
df_taxi_clean.dtypes
# Out:
# pickup             datetime64[ns]
# dropoff            datetime64[ns]
# passengers               category
# distance                  float64
# fare                      float64
# tip                       float64
# tolls                     float64
# total                     float64
# color                      object
# payment                    object
# pickup_zone                object
# dropoff_zone               object
# pickup_borough             object
# dropoff_borough            object
# dtype: object

# %%
sns.countplot(
    data=df_taxi_clean[df_taxi_clean['pickup_borough'] != 'NA'],
    x='passengers'
);
# Out:
# <Axes: xlabel='passengers', ylabel='count'>

# %%
boroughs = df_taxi_clean[df_taxi_clean['pickup_borough'] != 'NA']['pickup_borough'].unique()

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
axes = axes.flatten()

for i, borough in enumerate(boroughs):
    sns.countplot(
    data=df_taxi_clean[df_taxi_clean['pickup_borough'] == borough],
    x='passengers',
    ax=axes[i]
    )

    axes[i].set_title(f"{borough}")
    axes[i].set_xlabel("Passengers")

plt.tight_layout()
plt.show()

# %% [markdown]
# Більшість викликів таксі відбувається саме на 1 людину – тут можна подумати про оптимізацію (наприклад, за меншу вартість пропонувати користувачу погоджуватись їхати з людиною, яка протягом 5 хвилин викликала таксі в радіусі 5 км). Можливо, подумати про тип авто, які відправляють на такі виклики (можна оптимізувати)

# %% [markdown]
# 2. Середня тривалість поїздки в залежності від району

# %%
df_taxi_clean['trip_duration_min'] = (df_taxi_clean['dropoff'] - df_taxi_clean['pickup']).astype('timedelta64[m]')
df_taxi_clean.head()
# Out:
#                pickup             dropoff passengers  distance  fare   tip  \
# 0 2019-03-23 20:21:09 2019-03-23 20:27:24          1      1.60   7.0  2.15
# 1 2019-03-04 16:11:55 2019-03-04 16:19:00          1      0.79   5.0  0.00
# 2 2019-03-27 17:53:01 2019-03-27 18:00:25          1      1.37   7.5  2.36
# 3 2019-03-10 01:23:59 2019-03-10 01:49:51          1      7.70  27.0  6.15
# 4 2019-03-30 13:27:42 2019-03-30 13:37:14          3      2.16   9.0  1.10
#
#    tolls  total   color      payment            pickup_zone  \
# 0    0.0  12.95  yellow  credit card        Lenox Hill West
# 1    0.0   9.30  yellow         cash  Upper West Side South
# 2    0.0  14.16  yellow  credit card          Alphabet City
# 3    0.0  36.95  yellow  credit card              Hudson Sq
# 4    0.0  13.40  yellow  credit card           Midtown East
#
#             dropoff_zone pickup_borough dropoff_borough  trip_duration_min
# 0    UN/Turtle Bay South      Manhattan       Manhattan                6.0
# 1  Upper West Side South      Manhattan       Manhattan                7.0
# 2           West Village      Manhattan       Manhattan                7.0
# 3         Yorkville West      Manhattan       Manhattan               25.0
# 4         Yorkville West      Manhattan       Manhattan                9.0

# %%
sns.barplot(
    data=df_taxi_clean[df_taxi_clean['pickup_borough'] != 'NA'],
    x='pickup_borough',
    y='trip_duration_min'
);

# %% [markdown]
# Бачимо, що середня тривалість поїдки найбільша у Queens та Bronx. Цікаво, чи корелює це з середньою дистанцією поїдки.

# %%
sns.barplot(
    data=df_taxi_clean[df_taxi_clean['pickup_borough'] != 'NA'],
    x='pickup_borough',
    y='distance'
);

# %% [markdown]
# Цікаво, що у Queens довжина поїздки більша, хоч і тривалість +- така ж, як і Bronx. Можна це подосліджувати далі: можливо, десь довше чекають, чи повільніше їде (чи можна це оптимізувати?)

# %% [markdown]
# 3. Чи залежить метод оплати від району?

# %%
sns.countplot(
    data=df_taxi_clean[df_taxi_clean['pickup_borough'] != 'NA'],
    x='pickup_borough',
    hue='payment'
);

# %% [markdown]
# Все ж таки більшість оплачують карткою (особливо різницю видно в Манхеттені). Це можна використати і подосліджувати: чи можна сказати, що ті, хто оплачують готікою, залишають чайові з більшою ймовірністю? Якщо так, то робити якісь програми в додатку для заохочення і т.д.
